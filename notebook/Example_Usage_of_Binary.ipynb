# %% [markdown]
# ```
# CNN Based Autoencoder Application in Breast Cancer Image Retrieval 🔬
# - In this case I already splitted dataset
# - Please check your drive first and change where you wanna go use
# - This Is example usage dataset 40X Magnification with Binary label
# - All cell process must be done sequencely
# - I know maybe there is cumbersome case, Feel free to ask at kharisma.muzaki@gmail.com 👌
# ```

# %% [markdown]
# # Load Drive and Depedency

# %%
from google.colab import drive
drive.mount('/content/drive')
# CHANGE BASED ROOT DIR
# %cd '/content/drive/MyDrive/Image Retrieval'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Image Retrieval

# %% [markdown]
# ## Depedency Library

# %%
import numpy as np
import json
import os
import cv2
import copy
import sklearn.metrics as metric
import pandas as pd

from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint 

import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# # Training Stage

# %% [markdown]
# ## Core Model AutoEncoder

# %%
class ConvAutoEncoder:
    """
    Core Convolutional AutoEncoder
    This class included with build method you can adjust of width height and depth of image
    default filters 128, and latent dimension 48
    """
    @staticmethod
    def build(width, height, depth, filters=(128,), latent_dim=48):
        input_shape = (height, width, depth)
        channel_dim = -1
        inputs = layers.Input(shape=input_shape)
        x = inputs
        # Encoder layer
        for f in filters:
            x = layers.Conv2D(f, (3, 3), strides=2, padding='same')(x)
            x = layers.LeakyReLU(alpha=0.2)(x)
            x = layers.BatchNormalization(axis=channel_dim, name='enc_filter_' + str(f))(x)
        volume_size = K.int_shape(x)
        x = layers.Flatten()(x)
        # Latent layer
        latent = layers.Dense(latent_dim, name="encoded")(x)
        # Decoder layer
        x = layers.Dense(np.prod(volume_size[1:]))(latent)
        x = layers.Reshape((volume_size[1], volume_size[2], volume_size[3]))(x)
        # Reverse on decoder
        for f in filters[::-1]:
            x = layers.Conv2DTranspose(f, (3, 3), strides=2, padding='same')(x)
            x = layers.LeakyReLU(alpha=0.2)(x)
            x = layers.BatchNormalization(axis=channel_dim, name='dec_filter_' + str(f))(x)
        x = layers.Conv2DTranspose(depth, (3, 3), padding="same")(x)
        outputs = layers.Activation("sigmoid", name="decoded")(x)
        auto_encoder = Model(inputs, outputs, name="auto_encoder")
        return auto_encoder

# %% [markdown]
# ## Definition of hyperparameter

# %%
EPOCHS = 50
INIT_LR = 1e-3
BS = 16
IMAGE_SIZE = (256, 256)
checkpoint_path = "training_1_40_binary_cp/cp.ckpt"
feature_path = "training_1_40_binary_feature.json"
model_path = "training_1_40_binary_model.h5"
history_path = "training_1_40_binary_history.json"
magnification = "40X"
base_dataset = "binary_scenario"
class_dir = ['benign', 'malignant']

# %% [markdown]
# ## Load Image
#
#
# ```
# # Load all available file first then process to load images into variable
# ```

# %%
print("[INFO] indexing file images BreaKHis dataset...")
type_dataset = ['val', 'train']
dataset_train = []
dataset_val = []
for type_set in type_dataset:
    for class_item in class_dir:
        cur_dir = os.path.join(base_dataset, type_set, magnification ,class_item)
        for file in os.listdir(cur_dir):
            if type_set == 'train':
                dataset_train.append(os.path.join(cur_dir, file))
            else:
                dataset_val.append(os.path.join(cur_dir, file))

print("[INFO] load images BreaKHis dataset...")
#  load images
train_images = []
val_images = []
for type_set in type_dataset:
    cur_dataset = dataset_train if type_set == 'train' else dataset_val
    for image_path in cur_dataset:
        if ".png" in image_path:
            image = cv2.imread(image_path)
            image = cv2.resize(image, IMAGE_SIZE)
            if type_set == 'train':
                train_images.append(image)
            else:
                val_images.append(image)
# Out:
# [INFO] indexing file images BreaKHis dataset...
# [INFO] load images BreaKHis dataset...

# %% [markdown]
# ## Normalization

# %%
# normalization
print("[INFO] normalization...")
train_x = np.array(train_images).astype("float32") / 255.0
val_x = np.array(val_images).astype("float32") / 255.0
# Out:
# [INFO] normalization...

# %% [markdown]
# ## Buiding Model based ConvAutoEncoder Class

# %%
print("[INFO] building auto encoder...")
auto_encoder = ConvAutoEncoder.build(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor="val_loss",
    verbose = 1,
    mode='min',
    save_best_only=True)
auto_encoder.compile(loss="mse", optimizer=opt)
auto_encoder.summary()
# Out:
# [INFO] building auto encoder...
# Model: "auto_encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 128)     3584
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 128, 128, 128)     0
# _________________________________________________________________
# enc_filter_128 (BatchNormali (None, 128, 128, 128)     512
# _________________________________________________________________
# flatten (Flatten)            (None, 2097152)           0
# _________________________________________________________________
# encoded (Dense)              (None, 48)                100663344
# _________________________________________________________________
# dense (Dense)                (None, 2097152)           102760448
# _________________________________________________________________
# reshape (Reshape)            (None, 128, 128, 128)     0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 256, 256, 128)     147584
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 256, 256, 128)     0
# _________________________________________________________________
# dec_filter_128 (BatchNormali (None, 256, 256, 128)     512
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 256, 256, 3)       3459
# _________________________________________________________________
# decoded (Activation)         (None, 256, 256, 3)       0
# =================================================================
# Total params: 203,579,443
# Trainable params: 203,578,931
# Non-trainable params: 512
# _________________________________________________________________

# %% [markdown]
# ## Training The Model

# %%
# train the convolutional auto encoder
print("[INFO] training auto encoder...")
H = auto_encoder.fit(
    train_x, train_x,
    shuffle=True,
    validation_data=(val_x, val_x),
    epochs=EPOCHS,
    callbacks = [checkpoint_callback], batch_size=BS)
# Out:
# [INFO] training auto encoder...
# Epoch 1/50
# 102/102 [==============================] - 104s 708ms/step - loss: 0.0391 - val_loss: 0.0183
#
# Epoch 00001: val_loss improved from inf to 0.01834, saving model to training_1_40_binary_cp/cp.ckpt
# Epoch 2/50
# 102/102 [==============================] - 71s 697ms/step - loss: 0.0131 - val_loss: 0.0154
#
# Epoch 00002: val_loss improved from 0.01834 to 0.01537, saving model to training_1_40_binary_cp/cp.ckpt
# Epoch 3/50
# 102/102 [==============================] - 72s 703ms/step - loss: 0.0103 - val_loss: 0.0170
#
# Epoch 00003: val_loss did not improve from 0.01537
# Epoch 4/50
# 102/102 [==============================] - 71s 691ms/step - loss: 0.0102 - val_loss: 0.0132
#
# Epoch 00004: val_loss improved from 0.01537 to 0.01323, saving model to training_1_40_binary_cp/cp.ckpt
# Epoch 5/50
# 102/102 [==============================] - 72s 701ms/step - loss: 0.0100 - val_loss: 0.0132
#
# Epoch 00005: val_loss improved from 0.01323 to 0.01320, saving model to training_1_40_binary_cp/cp.ckpt
# Epoch 6/50
# 102/102 [==============================] - 71s 694ms/step - loss: 0.0100 - val_loss: 0.0103
#
# Epoch 00006: val_loss improved from 0.01320 to 0.01028, saving model to training_1_40_binary_cp/cp.ckpt
# Epoch 7/50
# 102/102 [==============================] - 71s 695ms/step - loss: 0.0099 - val_loss: 0.0099
#
# Epoch 00007: val_loss improved from 0.01028 to 0.00994, saving model to training_1_40_binary_cp/cp.ckpt
# Epoch 8/50
# 102/102 [==============================] - 71s 693ms/step - loss: 0.0099 - val_loss: 0.0104
#
# Epoch 00008: val_loss did not improve from 0.00994
# Epoch 9/50
# 102/102 [==============================] - 70s 689ms/step - loss: 0.0098 - val_loss: 0.0097
#
# Epoch 00009: val_loss improved from 0.00994 to 0.00969, saving model to training_1_40_binary_cp/cp.ckpt
# Epoch 10/50
# 102/102 [==============================] - 71s 697ms/step - loss: 0.0098 - val_loss: 0.0100
#
# Epoch 00010: val_loss did not improve from 0.00969
# Epoch 11/50
# 102/102 [==============================] - 71s 691ms/step - loss: 0.0096 - val_loss: 0.0099
#
# Epoch 00011: val_loss did not improve from 0.00969
# Epoch 12/50
# 102/102 [==============================] - 70s 687ms/step - loss: 0.0095 - val_loss: 0.0097
#
# Epoch 00012: val_loss did not improve from 0.00969
# Epoch 13/50
# 102/102 [==============================] - 70s 688ms/step - loss: 0.0094 - val_loss: 0.0105
#
# Epoch 00013: val_loss did not improve from 0.00969
# Epoch 14/50
# 102/102 [==============================] - 70s 688ms/step - loss: 0.0094 - val_loss: 0.0098
#
# Epoch 00014: val_loss did not improve from 0.00969
# Epoch 15/50
# 102/102 [==============================] - 70s 687ms/step - loss: 0.0094 - val_loss: 0.0095
#
# Epoch 00015: val_loss improved from 0.00969 to 0.00953, saving model to training_1_40_binary_cp/cp.ckpt
# Epoch 16/50
# 102/102 [==============================] - 71s 700ms/step - loss: 0.0093 - val_loss: 0.0094
#
# Epoch 00016: val_loss improved from 0.00953 to 0.00942, saving model to training_1_40_binary_cp/cp.ckpt
# Epoch 17/50
# 102/102 [==============================] - 71s 694ms/step - loss: 0.0092 - val_loss: 0.0098
#
# Epoch 00017: val_loss did not improve from 0.00942
# Epoch 18/50
# 102/102 [==============================] - 71s 692ms/step - loss: 0.0092 - val_loss: 0.0100
#
# Epoch 00018: val_loss did not improve from 0.00942
# Epoch 19/50
# 102/102 [==============================] - 70s 688ms/step - loss: 0.0091 - val_loss: 0.0098
#
# Epoch 00019: val_loss did not improve from 0.00942
# Epoch 20/50
# 102/102 [==============================] - 70s 688ms/step - loss: 0.0091 - val_loss: 0.0096
#
# Epoch 00020: val_loss did not improve from 0.00942
# Epoch 21/50
# 102/102 [==============================] - 70s 687ms/step - loss: 0.0091 - val_loss: 0.0138
#
# Epoch 00021: val_loss did not improve from 0.00942
# Epoch 22/50
# 102/102 [==============================] - 70s 689ms/step - loss: 0.0089 - val_loss: 0.0096
#
# Epoch 00022: val_loss did not improve from 0.00942
# Epoch 23/50
# 102/102 [==============================] - 70s 687ms/step - loss: 0.0086 - val_loss: 0.0095
#
# Epoch 00023: val_loss did not improve from 0.00942
# Epoch 24/50
# 102/102 [==============================] - 70s 687ms/step - loss: 0.0086 - val_loss: 0.0097
#
# Epoch 00024: val_loss did not improve from 0.00942
# Epoch 25/50
# 102/102 [==============================] - 70s 689ms/step - loss: 0.0085 - val_loss: 0.0097
#
# Epoch 00025: val_loss did not improve from 0.00942
# Epoch 26/50
# 102/102 [==============================] - 70s 687ms/step - loss: 0.0086 - val_loss: 0.0098
#
# Epoch 00026: val_loss did not improve from 0.00942
# Epoch 27/50
# 102/102 [==============================] - 70s 688ms/step - loss: 0.0084 - val_loss: 0.0113
#
# Epoch 00027: val_loss did not improve from 0.00942
# Epoch 28/50
# 102/102 [==============================] - 70s 688ms/step - loss: 0.0082 - val_loss: 0.0097
#
# Epoch 00028: val_loss did not improve from 0.00942
# Epoch 29/50
# 102/102 [==============================] - 70s 687ms/step - loss: 0.0081 - val_loss: 0.0101
#
# Epoch 00029: val_loss did not improve from 0.00942
# Epoch 30/50
# 102/102 [==============================] - 70s 689ms/step - loss: 0.0079 - val_loss: 0.0130
#
# Epoch 00030: val_loss did not improve from 0.00942
# Epoch 31/50
# 102/102 [==============================] - 70s 688ms/step - loss: 0.0078 - val_loss: 0.0098
#
# Epoch 00031: val_loss did not improve from 0.00942
# Epoch 32/50
# 102/102 [==============================] - 70s 689ms/step - loss: 0.0075 - val_loss: 0.0101
#
# Epoch 00032: val_loss did not improve from 0.00942
# Epoch 33/50
# 102/102 [==============================] - 70s 688ms/step - loss: 0.0075 - val_loss: 0.0098
#
# Epoch 00033: val_loss did not improve from 0.00942
# Epoch 34/50
# 102/102 [==============================] - 70s 688ms/step - loss: 0.0074 - val_loss: 0.0114
#
# Epoch 00034: val_loss did not improve from 0.00942
# Epoch 35/50
# 102/102 [==============================] - 70s 689ms/step - loss: 0.0075 - val_loss: 0.0159
#
# Epoch 00035: val_loss did not improve from 0.00942
# Epoch 36/50
# 102/102 [==============================] - 70s 689ms/step - loss: 0.0078 - val_loss: 0.0109
#
# Epoch 00036: val_loss did not improve from 0.00942
# Epoch 37/50
# 102/102 [==============================] - 70s 687ms/step - loss: 0.0075 - val_loss: 0.0106
#
# Epoch 00037: val_loss did not improve from 0.00942
# Epoch 38/50
# 102/102 [==============================] - 70s 690ms/step - loss: 0.0070 - val_loss: 0.0108
#
# Epoch 00038: val_loss did not improve from 0.00942
# Epoch 39/50
# 102/102 [==============================] - 70s 687ms/step - loss: 0.0069 - val_loss: 0.0100
#
# Epoch 00039: val_loss did not improve from 0.00942
# Epoch 40/50
# 102/102 [==============================] - 70s 688ms/step - loss: 0.0067 - val_loss: 0.0105
#
# Epoch 00040: val_loss did not improve from 0.00942
# Epoch 41/50
# 102/102 [==============================] - 70s 689ms/step - loss: 0.0063 - val_loss: 0.0110
#
# Epoch 00041: val_loss did not improve from 0.00942
# Epoch 42/50
# 102/102 [==============================] - 70s 688ms/step - loss: 0.0062 - val_loss: 0.0102
#
# Epoch 00042: val_loss did not improve from 0.00942
# Epoch 43/50
# 102/102 [==============================] - 70s 689ms/step - loss: 0.0059 - val_loss: 0.0104
#
# Epoch 00043: val_loss did not improve from 0.00942
# Epoch 44/50
# 102/102 [==============================] - 70s 687ms/step - loss: 0.0058 - val_loss: 0.0110
#
# Epoch 00044: val_loss did not improve from 0.00942
# Epoch 45/50
# 102/102 [==============================] - 70s 687ms/step - loss: 0.0054 - val_loss: 0.0110
#
# Epoch 00045: val_loss did not improve from 0.00942
# Epoch 46/50
# 102/102 [==============================] - 70s 689ms/step - loss: 0.0054 - val_loss: 0.0118
#
# Epoch 00046: val_loss did not improve from 0.00942
# Epoch 47/50
# 102/102 [==============================] - 70s 687ms/step - loss: 0.0058 - val_loss: 0.0109
#
# Epoch 00047: val_loss did not improve from 0.00942
# Epoch 48/50
# 102/102 [==============================] - 70s 687ms/step - loss: 0.0053 - val_loss: 0.0123
#
# Epoch 00048: val_loss did not improve from 0.00942
# Epoch 49/50
# 102/102 [==============================] - 70s 687ms/step - loss: 0.0052 - val_loss: 0.0109
#
# Epoch 00049: val_loss did not improve from 0.00942
# Epoch 50/50
# 102/102 [==============================] - 70s 689ms/step - loss: 0.0051 - val_loss: 0.0140
#
# Epoch 00050: val_loss did not improve from 0.00942

# %% [markdown]
# ## Saved Result Graphic (.json) and Model Trained (h5)

# %%
with open(history_path, 'w') as f:
    json.dump(H.history, f)
auto_encoder.save(model_path)

# %% [markdown]
# # Extract Feature Stage

# %% [markdown]
# ## Load already trained model and extracting feature

# %%
auto_encoder = ConvAutoEncoder.build(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
# load our auto_encoder from disk
print("[INFO] loading auto encoder model...")
auto_encoder.load_weights(checkpoint_path)

# create the encoder model which consists of *just* the encoder
# portion of the auto encoder
encoder = Model(inputs=auto_encoder.input,
	outputs=auto_encoder.get_layer("encoded").output)

# quantify the contents of our input images using the encoder
print("[INFO] encoding images...")
features = encoder.predict(train_x)
# Out:
# [INFO] loading auto encoder model...
# [INFO] encoding images...

# %% [markdown]
# ## Create mapping feature included location images, label, feature and indexing number

# %%
indexes = list(range(0, train_x.shape[0]))
features_array = [[float(x) for x in y] for y in features]
labels = [path.split("/")[3] for path in dataset_train]
data = {"indexes": indexes, "features": features_array, "locations": dataset_train, "labels":labels}

# %% [markdown]
# ## Saved model feature (already mapped) as json

# %%
with open(feature_path, 'w') as f:
    json.dump(data, f)

# %% [markdown]
# # Retrieval Test Stage

# %% [markdown]
# ## Euclidean function

# %%
def euclidean(a, b):
	# compute and return the euclidean distance between two vectors
	return np.linalg.norm(a - b)

# %% [markdown]
# ## Perform search function
# ```
# Default max result from search is 5
# ```

# %%
def perform_search(query_features, indexed_train, max_results=5):
	retrieved = []
	for idx in range(0, len(indexed_train["features"])):
		distance = euclidean(query_features, indexed_train["features"][idx])
		retrieved.append((distance, idx))
	retrieved = sorted(retrieved)[:max_results]
	return retrieved

# %% [markdown]
# ## Load test images

# %%
print("[INFO] indexing file images BreaKHis dataset...")
# indexing file images
dataset = []
for class_item in class_dir:
    cur_dir = os.path.join(base_dataset, 'test', magnification, class_item)
    for file in os.listdir(cur_dir):
        dataset.append(os.path.join(cur_dir, file))
print("test len to retrieving:", len(dataset))
print("[INFO] load test images BreaKHis dataset...")
#  load images
images = []
for image_path in dataset:
    if ".png" in image_path:
        image = cv2.imread(image_path)
        image = cv2.resize(image, IMAGE_SIZE)
        images.append(image)
# Out:
# [INFO] indexing file images BreaKHis dataset...
# test len to retrieving: 199
# [INFO] load test images BreaKHis dataset...

# %% [markdown]
# ## Normalization

# %%
# normalization
print("[INFO] normalization...")
test_x = np.array(images).astype("float32") / 255.0
# Out:
# [INFO] normalization...

# %% [markdown]
# ## Load the model and feature already extracted

# %%
auto_encoder = ConvAutoEncoder.build(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
# load our auto_encoder from disk
print("[INFO] loading auto encoder model...")
auto_encoder.load_weights(checkpoint_path)
with open(feature_path) as f:
  training_indexed = json.load(f)

# create the encoder model which consists of *just* the encoder
# portion of the auto encoder
encoder = Model(inputs=auto_encoder.input,
	outputs=auto_encoder.get_layer("encoded").output)

# quantify the contents of our input images using the encoder
print("[INFO] encoding images...")
features_retrieved = encoder.predict(test_x)
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-5.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-5.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-6.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-5.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-5.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-6.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# [INFO] loading auto encoder model...
# [INFO] encoding images...

# %% [markdown]
# ## Perform search and retrieval based test images

# %%
query_indexes = list(range(0, test_x.shape[0]))
label_builder = list(np.unique(training_indexed["labels"]))
class_builder = {label_unique:[] for label_unique in label_builder}
recalls = copy.deepcopy(class_builder)
precisions = copy.deepcopy(class_builder)
# loop over the testing indexes
for i in query_indexes:
    queryFeatures = features_retrieved[i]
    results = perform_search(queryFeatures, training_indexed, max_results=5)
    labels_ret = [training_indexed["labels"][r[1]] for r in results]
    label_true = dataset[i].split("/")[3]
    label_trues = [label_true for _ in labels_ret]
    recall = metric.recall_score(label_trues, labels_ret, average='weighted')
    precision = metric.precision_score(label_trues, labels_ret, average='weighted')
    recalls[label_true].append(recall)
    precisions[label_true].append(precision)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Print the recall and precision values

# %%
print("recall values:")
comb_recall, comb_precision = [], []
for key in recalls.keys():
    average_val = np.average(recalls[key])
    print(key, average_val)
    comb_recall.append(average_val)
print("combined recall", np.average(comb_recall))

print("\nprecision values:")
for key in precisions.keys():
    average_val = np.average(precisions[key])
    print(key, average_val)
    comb_precision.append(average_val)
print("combined precision", np.average(comb_precision))
# Out:
# recall values:
# benign 0.7387096774193549
# malignant 0.872992700729927
# combined recall 0.8058511890746409
#
# precision values:
# benign 0.967741935483871
# malignant 0.9927007299270073
# combined precision 0.9802213327054392
